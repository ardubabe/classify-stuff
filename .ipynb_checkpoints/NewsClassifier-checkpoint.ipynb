# %%
import pandas as pd

# %%
# set the path to our file
path = 'NewsCategorizer.csv'
# convert our csv file to a pandas DataFrame
# converters allows pandas to know that abilities is a list, not a string
news = pd.read_csv(path)

# %%
news
# Out:
#        category                                           headline  \
# 0      WELLNESS              143 Miles in 35 Days: Lessons Learned
# 1      WELLNESS       Talking to Yourself: Crazy or Crazy Helpful?
# 2      WELLNESS  Crenezumab: Trial Will Gauge Whether Alzheimer...
# 3      WELLNESS                     Oh, What a Difference She Made
# 4      WELLNESS                                   Green Superfoods
# ...         ...                                                ...
# 49995    SPORTS  This Baseball Team Learned There's A Wrong Way...
# 49996    SPORTS  Some Young Spurs Fan Dabbed 38 Times In A Sing...
# 49997    SPORTS  Rasheed Wallace Ejected From Knicks-Suns Game ...
# 49998    SPORTS  Why Jake Plummer And Other NFL Players Are Pus...
# 49999    SPORTS  Simone Biles Isn't The Next Anyone, She's 'The...
#
#                                                    links  \
# 0      https://www.huffingtonpost.com/entry/running-l...
# 1      https://www.huffingtonpost.com/entry/talking-t...
# 2      https://www.huffingtonpost.com/entry/crenezuma...
# 3      https://www.huffingtonpost.com/entry/meaningfu...
# 4      https://www.huffingtonpost.com/entry/green-sup...
# ...                                                  ...
# 49995  https://www.huffingtonpost.com/entry/san-jose-...
# 49996  https://www.huffingtonpost.com/entry/dab-kid-s...
# 49997  https://www.huffingtonpost.com/entry/rasheed-w...
# 49998  https://www.huffingtonpost.comhttp://extras.de...
# 49999  https://www.huffingtonpost.com/entry/the-first...
#
#                                        short_description  \
# 0      Resting is part of training. I've confirmed wh...
# 1      Think of talking to yourself as a tool to coac...
# 2      The clock is ticking for the United States to ...
# 3      If you want to be busy, keep trying to be perf...
# 4      First, the bad news: Soda bread, corned beef a...
# ...                                                  ...
# 49995  Many fans were pissed after seeing the minor l...
# 49996             Never change, young man. Never change.
# 49997  Wallace was hit with a first technical for a h...
# 49998  They believe CBD could be an alternative to po...
# 49999             The gymnast is in a league of her own.
#
#                                                 keywords
# 0                                        running-lessons
# 1                              talking-to-yourself-crazy
# 2                     crenezumab-alzheimers-disease-drug
# 3                                        meaningful-life
# 4                                       green-superfoods
# ...                                                  ...
# 49995            san-jose-giants-japanese-heritage-night
# 49996                          dab-kid-san-antonio-spurs
# 49997  rasheed-wallace-ejected-knicks-suns-ball-dont-lie
# 49998                                                NaN
# 49999                             the-first-simone-biles
#
# [50000 rows x 5 columns]

# %%
len(news.category.unique())
# Out:
# 10

# %%
news.category.unique()
# Out:
# array(['WELLNESS', 'POLITICS', 'ENTERTAINMENT', 'TRAVEL',
#        'STYLE & BEAUTY', 'PARENTING', 'FOOD & DRINK', 'WORLD NEWS',
#        'BUSINESS', 'SPORTS'], dtype=object)

# %%
from stop_words import get_stop_words
# if "No module named 'stop_words'" error; yuo haven't imported a library, shut down everyhting and import in terminal

# {'first_keyword': shdfshdf, 'second_keyword': uagdfgafh, 'third_keyword': ousgeaofuqge}
def create_features(headline):
    # make all the words lowercase
    headline = headline.lower()
    # split the headline into a list of words
    words = headline.split()
    # using list comprehension to create a list of keywords
    keywords = [ x for x in words if x not in get_stop_words('english') ]
    # make sure all keyword lists have three elements
    while len(keywords) < 3:
        keywords.append('None')
    return {'first_keyword': keywords[0], 'second_keyword': keywords[1], 'third_keyword': keywords[2]}

# %%
zipped_feature_and_labels = zip(news.headline, news.category)

# %%
# bring together the catergory(label), and the headline(features)

# we are creating a list of tuples
# tuples have parenthesies around them -> (create_features(headline), category)
feature_sets = [ (create_features(headline), category) for headline, category in zipped_feature_and_labels ]
feature_sets
# Out:
# [({'first_keyword': '143', 'second_keyword': 'miles', 'third_keyword': '35'},
#   'WELLNESS'),
#  ({'first_keyword': 'talking',
#    'second_keyword': 'yourself:',
#    'third_keyword': 'crazy'},
#   'WELLNESS'),
#  ({'first_keyword': 'crenezumab:',
#    'second_keyword': 'trial',
#    'third_keyword': 'will'},
#   'WELLNESS'),
#  ({'first_keyword': 'oh,',
#    'second_keyword': 'difference',
#    'third_keyword': 'made'},
#   'WELLNESS'),
#  ({'first_keyword': 'green',
#    'second_keyword': 'superfoods',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'bad',
#    'second_keyword': 'love',
#    'third_keyword': 'advice:'},
#   'WELLNESS'),
#  ({'first_keyword': 'happiest',
#    'second_keyword': '(and',
#    'third_keyword': 'unhappiest)'},
#   'WELLNESS'),
#  ({'first_keyword': 'seaweed:',
#    'second_keyword': 'green',
#    'third_keyword': 'superfood'},
#   'WELLNESS'),
#  ({'first_keyword': 'addicted',
#    'second_keyword': 'food?',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'high',
#    'second_keyword': 'tech',
#    'third_keyword': 'works'},
#   'WELLNESS'),
#  ({'first_keyword': 'conflict:',
#    'second_keyword': '7',
#    'third_keyword': 'decisions'},
#   'WELLNESS'),
#  ({'first_keyword': 'case',
#    'second_keyword': 'lifting',
#    'third_keyword': 'heavy'},
#   'WELLNESS'),
#  ({'first_keyword': 'show',
#    'second_keyword': 'kindness:',
#    'third_keyword': 'good'},
#   'WELLNESS'),
#  ({'first_keyword': 'time',
#    'second_keyword': 'sweep',
#    'third_keyword': 'confetti'},
#   'WELLNESS'),
#  ({'first_keyword': 'mysterious',
#    'second_keyword': 'illness',
#    'third_keyword': 'le'},
#   'WELLNESS'),
#  ({'first_keyword': 'top',
#    'second_keyword': 'lungs:',
#    'third_keyword': 'sickness'},
#   'WELLNESS'),
#  ({'first_keyword': 'beautiful',
#    'second_keyword': 'places',
#    'third_keyword': 'nap'},
#   'WELLNESS'),
#  ({'first_keyword': 'antibiotics',
#    'second_keyword': 'making',
#    'third_keyword': 'us'},
#   'WELLNESS'),
#  ({'first_keyword': 'fearless',
#    'second_keyword': 'children',
#    'third_keyword': 'can'},
#   'WELLNESS'),
#  ({'first_keyword': 'paper-centered',
#    'second_keyword': 'care',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'glenwood',
#    'second_keyword': 'gardens',
#    'third_keyword': 'case'},
#   'WELLNESS'),
#  ({'first_keyword': 'overcoming',
#    'second_keyword': 'naysayers',
#    'third_keyword': 'sabotagers'},
#   'WELLNESS'),
#  ({'first_keyword': 'pesticides',
#    'second_keyword': 'personal',
#    'third_keyword': 'care'},
#   'WELLNESS'),
#  ({'first_keyword': 'woman,',
#    'second_keyword': 'deconstructed',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'tv,',
#    'second_keyword': 'computer',
#    'third_keyword': 'ownership'},
#   'WELLNESS'),
#  ({'first_keyword': 'lost',
#    'second_keyword': 'weight:',
#    'third_keyword': 'debbie'},
#   'WELLNESS'),
#  ({'first_keyword': 'coca-cola',
#    'second_keyword': 'makes',
#    'third_keyword': 'thin?'},
#   'WELLNESS'),
#  ({'first_keyword': '10', 'second_keyword': 'best', 'third_keyword': 'yoga'},
#   'WELLNESS'),
#  ({'first_keyword': 'lost',
#    'second_keyword': 'weight:',
#    'third_keyword': 'health'},
#   'WELLNESS'),
#  ({'first_keyword': 'choice',
#    'second_keyword': 'theory',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'myth',
#    'second_keyword': 'creative',
#    'third_keyword': 'inspiration:'},
#   'WELLNESS'),
#  ({'first_keyword': 'cholera',
#    'second_keyword': 'epidemic',
#    'third_keyword': 'began'},
#   'WELLNESS'),
#  ({'first_keyword': 'oprah',
#    'second_keyword': 'caroline',
#    'third_keyword': 'myss:'},
#   'WELLNESS'),
#  ({'first_keyword': 'exercise',
#    'second_keyword': 'decreases',
#    'third_keyword': 'nicotine'},
#   'WELLNESS'),
#  ({'first_keyword': 'black',
#    'second_keyword': 'friday',
#    'third_keyword': 'fitness:'},
#   'WELLNESS'),
#  ({'first_keyword': "bloomberg's",
#    'second_keyword': 'cap',
#    'third_keyword': 'supersize'},
#   'WELLNESS'),
#  ({'first_keyword': '#fitnessbucketlist',
#    'second_keyword': 'tweets',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'mistletoe',
#    'second_keyword': 'help',
#    'third_keyword': 'fight'},
#   'WELLNESS'),
#  ({'first_keyword': 'push',
#    'second_keyword': "girl'",
#    'third_keyword': 'auti'},
#   'WELLNESS'),
#  ({'first_keyword': 'healing',
#    'second_keyword': 'effect',
#    'third_keyword': 'sharing'},
#   'WELLNESS'),
#  ({'first_keyword': '30',
#    'second_keyword': 'things',
#    'third_keyword': 'learned'},
#   'WELLNESS'),
#  ({'first_keyword': 'community',
#    'second_keyword': 'gardens',
#    'third_keyword': 'linked'},
#   'WELLNESS'),
#  ({'first_keyword': 'sacred',
#    'second_keyword': 'feminine',
#    'third_keyword': 'today'},
#   'WELLNESS'),
#  ({'first_keyword': 'bounce',
#    'second_keyword': 'back',
#    'third_keyword': 'failure'},
#   'WELLNESS'),
#  ({'first_keyword': 'pet', 'second_keyword': 'says', 'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'notable',
#    'second_keyword': 'medical',
#    'third_keyword': 'news'},
#   'WELLNESS'),
#  ({'first_keyword': 'tis',
#    'second_keyword': 'season',
#    'third_keyword': 'stressed:'},
#   'WELLNESS'),
#  ({'first_keyword': 'unlocking',
#    'second_keyword': 'mysteries',
#    'third_keyword': "life's"},
#   'WELLNESS'),
#  ({'first_keyword': 'thriving',
#    'second_keyword': 'just',
#    'third_keyword': 'surviving?'},
#   'WELLNESS'),
#  ({'first_keyword': 'gps',
#    'second_keyword': 'guide:',
#    'third_keyword': 'austin'},
#   'WELLNESS'),
#  ({'first_keyword': 'obamacare',
#    'second_keyword': 'starts',
#    'third_keyword': 'cracking'},
#   'WELLNESS'),
#  ({'first_keyword': 'hotels',
#    'second_keyword': 'let',
#    'third_keyword': 'guests'},
#   'WELLNESS'),
#  ({'first_keyword': 'tried',
#    'second_keyword': 'it:',
#    'third_keyword': 'antigravity'},
#   'WELLNESS'),
#  ({'first_keyword': 'weight',
#    'second_keyword': 'loss',
#    'third_keyword': 'success:'},
#   'WELLNESS'),
#  ({'first_keyword': 'incline',
#    'second_keyword': 'db',
#    'third_keyword': 'bench'},
#   'WELLNESS'),
#  ({'first_keyword': 'day', 'second_keyword': '19:', 'third_keyword': '31'},
#   'WELLNESS'),
#  ({'first_keyword': 'wakeup',
#    'second_keyword': 'call',
#    'third_keyword': "doctor's"},
#   'WELLNESS'),
#  ({'first_keyword': 'auriculotherapy:',
#    'second_keyword': 'penelope',
#    'third_keyword': 'cruz'},
#   'WELLNESS'),
#  ({'first_keyword': "life's",
#    'second_keyword': 'work',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'hormone',
#    'second_keyword': 'therapy',
#    'third_keyword': "'not"},
#   'WELLNESS'),
#  ({'first_keyword': 'lost',
#    'second_keyword': 'weight:',
#    'third_keyword': 'jesse'},
#   'WELLNESS'),
#  ({'first_keyword': 'chronic',
#    'second_keyword': 'stress',
#    'third_keyword': 'lowers'},
#   'WELLNESS'),
#  ({'first_keyword': 'simple',
#    'second_keyword': 'mental',
#    'third_keyword': 'trick'},
#   'WELLNESS'),
#  ({'first_keyword': 'olympic',
#    'second_keyword': 'fever',
#    'third_keyword': 'inspires'},
#   'WELLNESS'),
#  ({'first_keyword': 'presidents',
#    'second_keyword': 'day:',
#    'third_keyword': 'healthy'},
#   'WELLNESS'),
#  ({'first_keyword': 'grief',
#    'second_keyword': 'holidays:',
#    'third_keyword': '10'},
#   'WELLNESS'),
#  ({'first_keyword': 'can',
#    'second_keyword': 'make',
#    'third_keyword': 'others'},
#   'WELLNESS'),
#  ({'first_keyword': '7', 'second_keyword': 'ways', 'third_keyword': 'fall'},
#   'WELLNESS'),
#  ({'first_keyword': 'nutrition',
#    'second_keyword': 'tips:',
#    'third_keyword': '5'},
#   'WELLNESS'),
#  ({'first_keyword': 'antibiotic',
#    'second_keyword': 'research',
#    'third_keyword': 'development'},
#   'WELLNESS'),
#  ({'first_keyword': 'options,',
#    'second_keyword': 'problems',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': '6',
#    'second_keyword': 'free',
#    'third_keyword': 'screenings'},
#   'WELLNESS'),
#  ({'first_keyword': 'brown',
#    'second_keyword': 'fat:',
#    'third_keyword': 'smoke...'},
#   'WELLNESS'),
#  ({'first_keyword': 'winter',
#    'second_keyword': 'horoscope:',
#    'third_keyword': 'lovers'},
#   'WELLNESS'),
#  ({'first_keyword': '23andguvmt',
#    'second_keyword': '--',
#    'third_keyword': 'health'},
#   'WELLNESS'),
#  ({'first_keyword': 'super',
#    'second_keyword': 'bowl',
#    'third_keyword': 'sunday'},
#   'WELLNESS'),
#  ({'first_keyword': 'national',
#    'second_keyword': 'public',
#    'third_keyword': 'health'},
#   'WELLNESS'),
#  ({'first_keyword': 'eat',
#    'second_keyword': '(video)',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'stool',
#    'second_keyword': 'transplants',
#    'third_keyword': 'soon'},
#   'WELLNESS'),
#  ({'first_keyword': 'acupuncture:',
#    'second_keyword': 'alternative',
#    'third_keyword': 'drugs'},
#   'WELLNESS'),
#  ({'first_keyword': 'personal',
#    'second_keyword': 'master',
#    'third_keyword': 'plan'},
#   'WELLNESS'),
#  ({'first_keyword': 'melissa',
#    'second_keyword': 'vidal',
#    'third_keyword': 'lost'},
#   'WELLNESS'),
#  ({'first_keyword': 'math',
#    'second_keyword': 'anxiety?',
#    'third_keyword': 'maybe'},
#   'WELLNESS'),
#  ({'first_keyword': 'true',
#    'second_keyword': 'charisma',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': '6',
#    'second_keyword': 'amazing',
#    'third_keyword': 'benefits'},
#   'WELLNESS'),
#  ({'first_keyword': 'sleeping',
#    'second_keyword': 'band:',
#    'third_keyword': 'mike'},
#   'WELLNESS'),
#  ({'first_keyword': 'processed',
#    'second_keyword': 'meat',
#    'third_keyword': 'raises'},
#   'WELLNESS'),
#  ({'first_keyword': 'online',
#    'second_keyword': 'personality',
#    'third_keyword': 'quizzes'},
#   'WELLNESS'),
#  ({'first_keyword': 'gps', 'second_keyword': 'guide:', 'third_keyword': '7'},
#   'WELLNESS'),
#  ({'first_keyword': 'sleep?',
#    'second_keyword': '5',
#    'third_keyword': 'things'},
#   'WELLNESS'),
#  ({'first_keyword': 'healthier',
#    'second_keyword': 'halloween',
#    'third_keyword': 'snacking'},
#   'WELLNESS'),
#  ({'first_keyword': 'evidence',
#    'second_keyword': 'sleep',
#    'third_keyword': 'enhances'},
#   'WELLNESS'),
#  ({'first_keyword': 'huffpost',
#    'second_keyword': 'workouts:',
#    'third_keyword': "valentine's"},
#   'WELLNESS'),
#  ({'first_keyword': 'want',
#    'second_keyword': 'change',
#    'third_keyword': 'life?'},
#   'WELLNESS'),
#  ({'first_keyword': 'foods',
#    'second_keyword': 'vision:',
#    'third_keyword': '6'},
#   'WELLNESS'),
#  ({'first_keyword': 'moment',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'narcissists',
#    'second_keyword': 'better',
#    'third_keyword': 'job'},
#   'WELLNESS'),
#  ({'first_keyword': 'support',
#    'second_keyword': 'solutions',
#    'third_keyword': 'going'},
#   'WELLNESS'),
#  ({'first_keyword': 'patience',
#    'second_keyword': 'vs.',
#    'third_keyword': 'patients'},
#   'WELLNESS'),
#  ({'first_keyword': 'time',
#    'second_keyword': 'adults',
#    'third_keyword': 'stop'},
#   'WELLNESS'),
#  ({'first_keyword': 'applying',
#    'second_keyword': 'inside-out',
#    'third_keyword': 'understanding'},
#   'WELLNESS'),
#  ({'first_keyword': 'doctors',
#    'second_keyword': 'say',
#    'third_keyword': 'changes'},
#   'WELLNESS'),
#  ({'first_keyword': 'daily',
#    'second_keyword': 'multivitamin',
#    'third_keyword': 'improve'},
#   'WELLNESS'),
#  ({'first_keyword': 'world',
#    'second_keyword': 'constant',
#    'third_keyword': 'digital'},
#   'WELLNESS'),
#  ({'first_keyword': 'distress,',
#    'second_keyword': 'traumatic',
#    'third_keyword': 'stress,'},
#   'WELLNESS'),
#  ({'first_keyword': '7', 'second_keyword': 'ways', 'third_keyword': 'prepare'},
#   'WELLNESS'),
#  ({'first_keyword': 'pharmacists',
#    'second_keyword': 'may',
#    'third_keyword': 'unaware'},
#   'WELLNESS'),
#  ({'first_keyword': 'get', 'second_keyword': 'great', 'third_keyword': 'legs'},
#   'WELLNESS'),
#  ({'first_keyword': 'researchers',
#    'second_keyword': 'question',
#    'third_keyword': 'vitamin'},
#   'WELLNESS'),
#  ({'first_keyword': 'healthy',
#    'second_keyword': 'fish',
#    'third_keyword': 'guide:'},
#   'WELLNESS'),
#  ({'first_keyword': 'huffpost',
#    'second_keyword': 'workouts:',
#    'third_keyword': 'summer'},
#   'WELLNESS'),
#  ({'first_keyword': 'parental',
#    'second_keyword': 'guidance',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'people,',
#    'second_keyword': 'people',
#    'third_keyword': 'need'},
#   'WELLNESS'),
#  ({'first_keyword': 'stop',
#    'second_keyword': 'wasting',
#    'third_keyword': 'time'},
#   'WELLNESS'),
#  ({'first_keyword': 'school',
#    'second_keyword': 'concession',
#    'third_keyword': 'stands'},
#   'WELLNESS'),
#  ({'first_keyword': 'kathy',
#    'second_keyword': 'bates',
#    'third_keyword': 'undergoes'},
#   'WELLNESS'),
#  ({'first_keyword': 'personalized',
#    'second_keyword': 'biological',
#    'third_keyword': 'testing'},
#   'WELLNESS'),
#  ({'first_keyword': 'book',
#    'second_keyword': 'review:',
#    'third_keyword': 'brain-based'},
#   'WELLNESS'),
#  ({'first_keyword': '6',
#    'second_keyword': 'unexpected',
#    'third_keyword': 'ways'},
#   'WELLNESS'),
#  ({'first_keyword': '10',
#    'second_keyword': 'psychological',
#    'third_keyword': 'tricks'},
#   'WELLNESS'),
#  ({'first_keyword': 'defending',
#    'second_keyword': 'loss',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': '3',
#    'second_keyword': 'ways',
#    'third_keyword': 'presidential'},
#   'WELLNESS'),
#  ({'first_keyword': 'utis',
#    'second_keyword': 'can',
#    'third_keyword': 'caused'},
#   'WELLNESS'),
#  ({'first_keyword': 'probiotic',
#    'second_keyword': 'candidate',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': '5',
#    'second_keyword': 'workout',
#    'third_keyword': 'wardrobe'},
#   'WELLNESS'),
#  ({'first_keyword': 'talking',
#    'second_keyword': 'probiotics',
#    'third_keyword': 'women'},
#   'WELLNESS'),
#  ({'first_keyword': 'arianna',
#    'second_keyword': "huffington's",
#    'third_keyword': 'gps'},
#   'WELLNESS'),
#  ({'first_keyword': 'hidden',
#    'second_keyword': 'issue',
#    'third_keyword': 'affect'},
#   'WELLNESS'),
#  ({'first_keyword': 'continued',
#    'second_keyword': 'therapy',
#    'third_keyword': 'works'},
#   'WELLNESS'),
#  ({'first_keyword': 'doctor',
#    'second_keyword': 'fatigue',
#    'third_keyword': 'raises'},
#   'WELLNESS'),
#  ({'first_keyword': 'need',
#    'second_keyword': 'kill',
#    'third_keyword': 'heroes?'},
#   'WELLNESS'),
#  ({'first_keyword': 'humor',
#    'second_keyword': 'hurting',
#    'third_keyword': 'people?'},
#   'WELLNESS'),
#  ({'first_keyword': 'boston',
#    'second_keyword': 'celtics',
#    'third_keyword': 'hope'},
#   'WELLNESS'),
#  ({'first_keyword': 'guide',
#    'second_keyword': 'communicating',
#    'third_keyword': 'candidly'},
#   'WELLNESS'),
#  ({'first_keyword': 'william',
#    'second_keyword': 'rockefeller,',
#    'third_keyword': 'engineer'},
#   'WELLNESS'),
#  ({'first_keyword': 'health',
#    'second_keyword': 'gains',
#    'third_keyword': '--'},
#   'WELLNESS'),
#  ({'first_keyword': 'take',
#    'second_keyword': 'outside',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'video:',
#    'second_keyword': 'dining',
#    'third_keyword': 'friends'},
#   'WELLNESS'),
#  ({'first_keyword': 'synthetic',
#    'second_keyword': 'marijuana:',
#    'third_keyword': 'new'},
#   'WELLNESS'),
#  ({'first_keyword': 'barbell',
#    'second_keyword': 'push',
#    'third_keyword': 'press'},
#   'WELLNESS'),
#  ({'first_keyword': 'national',
#    'second_keyword': 'donut',
#    'third_keyword': 'day:'},
#   'WELLNESS'),
#  ({'first_keyword': 'dating',
#    'second_keyword': 'fears:',
#    'third_keyword': "'i"},
#   'WELLNESS'),
#  ({'first_keyword': 'global',
#    'second_keyword': 'spending',
#    'third_keyword': 'medicines'},
#   'WELLNESS'),
#  ({'first_keyword': 'joy',
#    'second_keyword': 'grace',
#    'third_keyword': 'loving'},
#   'WELLNESS'),
#  ({'first_keyword': 'medicine,',
#    'second_keyword': 'museums',
#    'third_keyword': 'spoons'},
#   'WELLNESS'),
#  ({'first_keyword': 'cancer:',
#    'second_keyword': 'uninvited',
#    'third_keyword': 'visitor,'},
#   'WELLNESS'),
#  ({'first_keyword': '7',
#    'second_keyword': 'productivity',
#    'third_keyword': 'apps'},
#   'WELLNESS'),
#  ({'first_keyword': 'liquid',
#    'second_keyword': 'form',
#    'third_keyword': 'tamiflu'},
#   'WELLNESS'),
#  ({'first_keyword': 'fungal',
#    'second_keyword': 'meningitis:',
#    'third_keyword': 'infection'},
#   'WELLNESS'),
#  ({'first_keyword': 'creative',
#    'second_keyword': 'ways',
#    'third_keyword': 'letting'},
#   'WELLNESS'),
#  ({'first_keyword': 'h7n9', 'second_keyword': 'bird', 'third_keyword': 'flu'},
#   'WELLNESS'),
#  ({'first_keyword': 'real',
#    'second_keyword': 'snack',
#    'third_keyword': 'food'},
#   'WELLNESS'),
#  ({'first_keyword': 'medicaid',
#    'second_keyword': 'patients',
#    'third_keyword': 'turn'},
#   'WELLNESS'),
#  ({'first_keyword': 'choose',
#    'second_keyword': 'want',
#    'third_keyword': 'feel'},
#   'WELLNESS'),
#  ({'first_keyword': 'twin',
#    'second_keyword': 'miracles',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'much',
#    'second_keyword': 'know',
#    'third_keyword': 'sleep?'},
#   'WELLNESS'),
#  ({'first_keyword': 'good',
#    'second_keyword': "night's",
#    'third_keyword': 'sleep'},
#   'WELLNESS'),
#  ({'first_keyword': 'fructose,',
#    'second_keyword': 'fruit,',
#    'third_keyword': 'frittering'},
#   'WELLNESS'),
#  ({'first_keyword': 'worst',
#    'second_keyword': 'holiday',
#    'third_keyword': 'drinks'},
#   'WELLNESS'),
#  ({'first_keyword': 'protecting',
#    'second_keyword': 'projecting',
#    'third_keyword': 'personal'},
#   'WELLNESS'),
#  ({'first_keyword': 'putting',
#    'second_keyword': 'words',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'stop',
#    'second_keyword': 'letting',
#    'third_keyword': "people's"},
#   'WELLNESS'),
#  ({'first_keyword': 'descent',
#    'second_keyword': 'hell',
#    'third_keyword': 'taught'},
#   'WELLNESS'),
#  ({'first_keyword': 'best',
#    'second_keyword': 'foods',
#    'third_keyword': 'headaches'},
#   'WELLNESS'),
#  ({'first_keyword': 'glaxosmithkline',
#    'second_keyword': 'offering',
#    'third_keyword': '$1'},
#   'WELLNESS'),
#  ({'first_keyword': '3', 'second_keyword': 'ways', 'third_keyword': 'zap'},
#   'WELLNESS'),
#  ({'first_keyword': 'sweet',
#    'second_keyword': 'nothings,',
#    'third_keyword': 'bitter'},
#   'WELLNESS'),
#  ({'first_keyword': 'original',
#    'second_keyword': 'copycat',
#    'third_keyword': 'world'},
#   'WELLNESS'),
#  ({'first_keyword': 'walked',
#    'second_keyword': 'away',
#    'third_keyword': 'six-figure'},
#   'WELLNESS'),
#  ({'first_keyword': 'meditation',
#    'second_keyword': 'help',
#    'third_keyword': 'students'},
#   'WELLNESS'),
#  ({'first_keyword': 'internet',
#    'second_keyword': 'addiction:',
#    'third_keyword': 'just'},
#   'WELLNESS'),
#  ({'first_keyword': 'spiritual',
#    'second_keyword': 'leader',
#    'third_keyword': 'byron'},
#   'WELLNESS'),
#  ({'first_keyword': 'football:',
#    'second_keyword': 'much',
#    'third_keyword': 'ado'},
#   'WELLNESS'),
#  ({'first_keyword': 'power',
#    'second_keyword': 'thought',
#    'third_keyword': 'can'},
#   'WELLNESS'),
#  ({'first_keyword': 'resist',
#    'second_keyword': 'temptation',
#    'third_keyword': 'actually'},
#   'WELLNESS'),
#  ({'first_keyword': 'sleeping',
#    'second_keyword': 'pills',
#    'third_keyword': 'risks:'},
#   'WELLNESS'),
#  ({'first_keyword': 'victrelis',
#    'second_keyword': 'incivek,',
#    'third_keyword': 'rival'},
#   'WELLNESS'),
#  ({'first_keyword': '10',
#    'second_keyword': 'questions',
#    'third_keyword': 'ask'},
#   'WELLNESS'),
#  ({'first_keyword': 'optimism',
#    'second_keyword': 'needs',
#    'third_keyword': 'dose'},
#   'WELLNESS'),
#  ({'first_keyword': 'meaning',
#    'second_keyword': 'addiction',
#    'third_keyword': 'changed'},
#   'WELLNESS'),
#  ({'first_keyword': 'painkiller',
#    'second_keyword': 'sky?',
#    'third_keyword': 'sunshine'},
#   'WELLNESS'),
#  ({'first_keyword': '6',
#    'second_keyword': 'research-backed',
#    'third_keyword': 'tricks'},
#   'WELLNESS'),
#  ({'first_keyword': 'call',
#    'second_keyword': 'forth',
#    'third_keyword': 'divine'},
#   'WELLNESS'),
#  ({'first_keyword': 'overcoming',
#    'second_keyword': 'procrastination:',
#    'third_keyword': '7'},
#   'WELLNESS'),
#  ({'first_keyword': '3',
#    'second_keyword': 'must-try',
#    'third_keyword': 'strategies'},
#   'WELLNESS'),
#  ({'first_keyword': 'modern',
#    'second_keyword': 'stressors,',
#    'third_keyword': 'zebras'},
#   'WELLNESS'),
#  ({'first_keyword': 'calculated',
#    'second_keyword': 'risk:',
#    'third_keyword': 'wild'},
#   'WELLNESS'),
#  ({'first_keyword': 'michael',
#    'second_keyword': 'h.',
#    'third_keyword': "brooks's"},
#   'WELLNESS'),
#  ({'first_keyword': 'show',
#    'second_keyword': 'prostate',
#    'third_keyword': 'love'},
#   'WELLNESS'),
#  ({'first_keyword': 'migraine',
#    'second_keyword': 'triggers:',
#    'third_keyword': '10'},
#   'WELLNESS'),
#  ({'first_keyword': '6',
#    'second_keyword': 'personality',
#    'third_keyword': 'traits'},
#   'WELLNESS'),
#  ({'first_keyword': 'soda',
#    'second_keyword': 'games',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'music',
#    'second_keyword': 'sound',
#    'third_keyword': 'sleep'},
#   'WELLNESS'),
#  ({'first_keyword': 'bounce',
#    'second_keyword': 'back',
#    'third_keyword': 'life'},
#   'WELLNESS'),
#  ({'first_keyword': 'jennifer',
#    'second_keyword': 'smith',
#    'third_keyword': 'changed'},
#   'WELLNESS'),
#  ({'first_keyword': "mother's",
#    'second_keyword': 'strength',
#    'third_keyword': "daughter's"},
#   'WELLNESS'),
#  ({'first_keyword': 'sleep',
#    'second_keyword': 'way',
#    'third_keyword': 'creativity'},
#   'WELLNESS'),
#  ({'first_keyword': 'philip',
#    'second_keyword': 'seymour',
#    'third_keyword': "hoffman's"},
#   'WELLNESS'),
#  ({'first_keyword': 'really',
#    'second_keyword': 'think',
#    'third_keyword': 'healthy'},
#   'WELLNESS'),
#  ({'first_keyword': '23andme',
#    'second_keyword': 'me:',
#    'third_keyword': 'personal'},
#   'WELLNESS'),
#  ({'first_keyword': 'rise',
#    'second_keyword': 'non-perfectionist',
#    'third_keyword': 'veganism,'},
#   'WELLNESS'),
#  ({'first_keyword': 'center',
#    'second_keyword': 'meningitis',
#    'third_keyword': 'scare,'},
#   'WELLNESS'),
#  ({'first_keyword': '2014',
#    'second_keyword': 'horoscope:',
#    'third_keyword': 'exciting'},
#   'WELLNESS'),
#  ({'first_keyword': 'investing',
#    'second_keyword': 'downward',
#    'third_keyword': 'dog'},
#   'WELLNESS'),
#  ({'first_keyword': 'best',
#    'second_keyword': 'fitness',
#    'third_keyword': 'trackers:'},
#   'WELLNESS'),
#  ({'first_keyword': 'ready,',
#    'second_keyword': 'set,',
#    'third_keyword': 'go!'},
#   'WELLNESS'),
#  ({'first_keyword': 'bipolar',
#    'second_keyword': 'disorder',
#    'third_keyword': 'really'},
#   'WELLNESS'),
#  ({'first_keyword': 'exactly',
#    'second_keyword': 'need',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'winter',
#    'second_keyword': 'hospital',
#    'third_keyword': 'intern:'},
#   'WELLNESS'),
#  ({'first_keyword': 'chicken',
#    'second_keyword': 'china?',
#    'third_keyword': 'worried'},
#   'WELLNESS'),
#  ({'first_keyword': 'god?', 'second_keyword': 'None', 'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'wedding',
#    'second_keyword': 'ring',
#    'third_keyword': 'became'},
#   'WELLNESS'),
#  ({'first_keyword': 'number',
#    'second_keyword': 'flu',
#    'third_keyword': 'illnesses'},
#   'WELLNESS'),
#  ({'first_keyword': "mother's",
#    'second_keyword': 'day',
#    'third_keyword': 'without'},
#   'WELLNESS'),
#  ({'first_keyword': 'green',
#    'second_keyword': 'tea',
#    'third_keyword': 'benefits:'},
#   'WELLNESS'),
#  ({'first_keyword': "'zero",
#    'second_keyword': "excuses'",
#    'third_keyword': 'playlist'},
#   'WELLNESS'),
#  ({'first_keyword': 'tuberculosis:',
#    'second_keyword': 'fewer',
#    'third_keyword': 'tb'},
#   'WELLNESS'),
#  ({'first_keyword': '8', 'second_keyword': 'best', 'third_keyword': 'apps'},
#   'WELLNESS'),
#  ({'first_keyword': '7',
#    'second_keyword': 'ingredients',
#    'third_keyword': 'healthy'},
#   'WELLNESS'),
#  ({'first_keyword': 'can', 'second_keyword': 'aim', 'third_keyword': 'long,'},
#   'WELLNESS'),
#  ({'first_keyword': '1', 'second_keyword': '25', 'third_keyword': 'patients'},
#   'WELLNESS'),
#  ({'first_keyword': 'way',
#    'second_keyword': 'happiness;',
#    'third_keyword': 'happiness'},
#   'WELLNESS'),
#  ({'first_keyword': 'waiting,',
#    'second_keyword': 'wishing',
#    'third_keyword': 'blaming:'},
#   'WELLNESS'),
#  ({'first_keyword': 'light',
#    'second_keyword': 'night',
#    'third_keyword': 'bad'},
#   'WELLNESS'),
#  ({'first_keyword': 'transcranial',
#    'second_keyword': 'direct-current',
#    'third_keyword': 'stimulation,'},
#   'WELLNESS'),
#  ({'first_keyword': 'love',
#    'second_keyword': 'get',
#    'third_keyword': 'cancer'},
#   'WELLNESS'),
#  ({'first_keyword': 'emotionally',
#    'second_keyword': 'intelligent',
#    'third_keyword': 'you?'},
#   'WELLNESS'),
#  ({'first_keyword': 'woman',
#    'second_keyword': 'drinks',
#    'third_keyword': 'soda'},
#   'WELLNESS'),
#  ({'first_keyword': 'sharing',
#    'second_keyword': 'opinions',
#    'third_keyword': 'feels'},
#   'WELLNESS'),
#  ({'first_keyword': 'ultimate',
#    'second_keyword': 'music',
#    'third_keyword': 'playlist,'},
#   'WELLNESS'),
#  ({'first_keyword': 'suppress,',
#    'second_keyword': 'express!',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'life:',
#    'second_keyword': 'participant',
#    'third_keyword': 'sport'},
#   'WELLNESS'),
#  ({'first_keyword': 'putting',
#    'second_keyword': "'i'",
#    'third_keyword': 'caregiving'},
#   'WELLNESS'),
#  ({'first_keyword': 'technomyalgia?',
#    'second_keyword': 'tips',
#    'third_keyword': 'relieve'},
#   'WELLNESS'),
#  ({'first_keyword': '8', 'second_keyword': 'ways', 'third_keyword': 'tell'},
#   'WELLNESS'),
#  ({'first_keyword': 'health',
#    'second_keyword': 'blog',
#    'third_keyword': 'roundup:'},
#   'WELLNESS'),
#  ({'first_keyword': 'bodhisattvas',
#    'second_keyword': 'political',
#    'third_keyword': 'engagement'},
#   'WELLNESS'),
#  ({'first_keyword': 'cognitive',
#    'second_keyword': 'behavioral',
#    'third_keyword': 'therapy'},
#   'WELLNESS'),
#  ({'first_keyword': 'weekly', 'second_keyword': 'rune', 'third_keyword': '--'},
#   'WELLNESS'),
#  ({'first_keyword': 'today',
#    'second_keyword': 'mind',
#    'third_keyword': 'tracey'},
#   'WELLNESS'),
#  ({'first_keyword': 'aspirin',
#    'second_keyword': 'linked',
#    'third_keyword': 'lower'},
#   'WELLNESS'),
#  ({'first_keyword': 'walking',
#    'second_keyword': 'linked',
#    'third_keyword': 'decreased'},
#   'WELLNESS'),
#  ({'first_keyword': 'spend',
#    'second_keyword': 'energy?',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'add',
#    'second_keyword': 'indoor',
#    'third_keyword': 'rowing'},
#   'WELLNESS'),
#  ({'first_keyword': 'body',
#    'second_keyword': 'worlds',
#    'third_keyword': 'pulse:'},
#   'WELLNESS'),
#  ({'first_keyword': 'happy',
#    'second_keyword': 'oktoberfest!',
#    'third_keyword': 'tapping'},
#   'WELLNESS'),
#  ({'first_keyword': 'best',
#    'second_keyword': 'new',
#    'third_keyword': "year's"},
#   'WELLNESS'),
#  ({'first_keyword': 'sleepy',
#    'second_keyword': 'transportation',
#    'third_keyword': 'workers'},
#   'WELLNESS'),
#  ({'first_keyword': 'boston',
#    'second_keyword': 'marathon',
#    'third_keyword': 'tragedy:'},
#   'WELLNESS'),
#  ({'first_keyword': 'married',
#    'second_keyword': 'veteran:',
#    'third_keyword': 'memories'},
#   'WELLNESS'),
#  ({'first_keyword': 'make', 'second_keyword': 'wish', 'third_keyword': 'upon'},
#   'WELLNESS'),
#  ({'first_keyword': '60%', 'second_keyword': 'people', 'third_keyword': 'go'},
#   'WELLNESS'),
#  ({'first_keyword': 'knew?',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'lose',
#    'second_keyword': 'weight,',
#    'third_keyword': 'lose'},
#   'WELLNESS'),
#  ({'first_keyword': 'nothing',
#    'second_keyword': 'changes,',
#    'third_keyword': 'nothing'},
#   'WELLNESS'),
#  ({'first_keyword': 'psychological',
#    'second_keyword': 'impact',
#    'third_keyword': 'boston'},
#   'WELLNESS'),
#  ({'first_keyword': 'dane',
#    'second_keyword': 'kaohelani',
#    'third_keyword': 'silva'},
#   'WELLNESS'),
#  ({'first_keyword': 'practical',
#    'second_keyword': 'wisdom:',
#    'third_keyword': 'right'},
#   'WELLNESS'),
#  ({'first_keyword': 'dealing',
#    'second_keyword': 'diagnostic',
#    'third_keyword': 'dilemma:'},
#   'WELLNESS'),
#  ({'first_keyword': 'anger',
#    'second_keyword': 'disorders,',
#    'third_keyword': 'inflammation'},
#   'WELLNESS'),
#  ({'first_keyword': 'fearless',
#    'second_keyword': 'post-9/11',
#    'third_keyword': 'world'},
#   'WELLNESS'),
#  ({'first_keyword': 'heart',
#    'second_keyword': 'attack',
#    'third_keyword': 'death'},
#   'WELLNESS'),
#  ({'first_keyword': 'tighten',
#    'second_keyword': 'core',
#    'third_keyword': 'ice'},
#   'WELLNESS'),
#  ({'first_keyword': 'creativity',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'best',
#    'second_keyword': 'workout',
#    'third_keyword': 'headphones'},
#   'WELLNESS'),
#  ({'first_keyword': 'used',
#    'second_keyword': 'married',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'reward',
#    'second_keyword': 'volunteer!',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'mindful',
#    'second_keyword': 'work',
#    'third_keyword': 'challenge,'},
#   'WELLNESS'),
#  ({'first_keyword': '8',
#    'second_keyword': 'nutritionists',
#    'third_keyword': 'share'},
#   'WELLNESS'),
#  ({'first_keyword': '10', 'second_keyword': 'beliefs', 'third_keyword': 'may'},
#   'WELLNESS'),
#  ({'first_keyword': 'relax!',
#    'second_keyword': 'productive',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'ever',
#    'second_keyword': 'food',
#    'third_keyword': 'emergency'},
#   'WELLNESS'),
#  ({'first_keyword': 'preventing',
#    'second_keyword': 'treating',
#    'third_keyword': 'influenza'},
#   'WELLNESS'),
#  ({'first_keyword': 'toronto',
#    'second_keyword': 'can',
#    'third_keyword': 'teach'},
#   'WELLNESS'),
#  ({'first_keyword': 'personality',
#    'second_keyword': 'revealed',
#    'third_keyword': 'heartbeat'},
#   'WELLNESS'),
#  ({'first_keyword': 'response',
#    'second_keyword': 'organic',
#    'third_keyword': 'debate'},
#   'WELLNESS'),
#  ({'first_keyword': 'sugar',
#    'second_keyword': 'might',
#    'third_keyword': 'affect'},
#   'WELLNESS'),
#  ({'first_keyword': 'mindfulness',
#    'second_keyword': 'everyday',
#    'third_keyword': 'life:'},
#   'WELLNESS'),
#  ({'first_keyword': 'get',
#    'second_keyword': 'good',
#    'third_keyword': 'change:'},
#   'WELLNESS'),
#  ({'first_keyword': 'depression:',
#    'second_keyword': 'medicate,',
#    'third_keyword': 'meditate'},
#   'WELLNESS'),
#  ({'first_keyword': 'sleep?', 'second_keyword': '7', 'third_keyword': 'steps'},
#   'WELLNESS'),
#  ({'first_keyword': 'enjoy',
#    'second_keyword': 'holidays',
#    'third_keyword': 'family!'},
#   'WELLNESS'),
#  ({'first_keyword': '10',
#    'second_keyword': 'at-home',
#    'third_keyword': 'moves'},
#   'WELLNESS'),
#  ({'first_keyword': 'technological',
#    'second_keyword': 'austerity',
#    'third_keyword': 'manifesto'},
#   'WELLNESS'),
#  ({'first_keyword': '10',
#    'second_keyword': 'secrets',
#    'third_keyword': 'making'},
#   'WELLNESS'),
#  ({'first_keyword': 'much', 'second_keyword': 'know', 'third_keyword': 'flu'},
#   'WELLNESS'),
#  ({'first_keyword': 'one-minute',
#    'second_keyword': 'manager',
#    'third_keyword': 'gets'},
#   'WELLNESS'),
#  ({'first_keyword': 'epilepsy:',
#    'second_keyword': 'condition',
#    'third_keyword': 'caused'},
#   'WELLNESS'),
#  ({'first_keyword': "negative'",
#    'second_keyword': 'interesting',
#    'third_keyword': 'advice'},
#   'WELLNESS'),
#  ({'first_keyword': 'seasons',
#    'second_keyword': 'love:',
#    'third_keyword': 'lessons'},
#   'WELLNESS'),
#  ({'first_keyword': 'weight',
#    'second_keyword': 'loss:',
#    'third_keyword': 'point?'},
#   'WELLNESS'),
#  ({'first_keyword': 'exercise',
#    'second_keyword': 'can',
#    'third_keyword': 'boost'},
#   'WELLNESS'),
#  ({'first_keyword': 'sleep',
#    'second_keyword': 'last',
#    'third_keyword': 'night?'},
#   'WELLNESS'),
#  ({'first_keyword': '5',
#    'second_keyword': 'steps',
#    'third_keyword': 'limitless'},
#   'WELLNESS'),
#  ({'first_keyword': '10', 'second_keyword': 'best', 'third_keyword': 'yoga'},
#   'WELLNESS'),
#  ({'first_keyword': 'depression:',
#    'second_keyword': 'letter',
#    'third_keyword': 'grandfather'},
#   'WELLNESS'),
#  ({'first_keyword': '10', 'second_keyword': 'fun', 'third_keyword': 'fitness'},
#   'WELLNESS'),
#  ({'first_keyword': 'tis',
#    'second_keyword': 'season',
#    'third_keyword': 'be...'},
#   'WELLNESS'),
#  ({'first_keyword': 'coffee:',
#    'second_keyword': 'poison',
#    'third_keyword': 'medicine?'},
#   'WELLNESS'),
#  ({'first_keyword': 'james',
#    'second_keyword': 'coffey,',
#    'third_keyword': 'massachusetts'},
#   'WELLNESS'),
#  ({'first_keyword': '7',
#    'second_keyword': 'superfoods',
#    'third_keyword': 'can'},
#   'WELLNESS'),
#  ({'first_keyword': 'want',
#    'second_keyword': 'feel?',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'psa',
#    'second_keyword': 'testing:',
#    'third_keyword': 'evidence'},
#   'WELLNESS'),
#  ({'first_keyword': 'inflammation',
#    'second_keyword': 'lower',
#    'third_keyword': 'prostate'},
#   'WELLNESS'),
#  ({'first_keyword': 'mindfulness',
#    'second_keyword': 'meditation:',
#    'third_keyword': '6'},
#   'WELLNESS'),
#  ({'first_keyword': 'love',
#    'second_keyword': 'addicted?',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'research',
#    'second_keyword': 'shows',
#    'third_keyword': 'meditation'},
#   'WELLNESS'),
#  ({'first_keyword': '5',
#    'second_keyword': 'top',
#    'third_keyword': 'congestion'},
#   'WELLNESS'),
#  ({'first_keyword': 'stressed',
#    'second_keyword': 'doctor?',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'maria',
#    'second_keyword': 'kang',
#    'third_keyword': 'problem:'},
#   'WELLNESS'),
#  ({'first_keyword': 'blood',
#    'second_keyword': 'sugar',
#    'third_keyword': 'solution'},
#   'WELLNESS'),
#  ({'first_keyword': 'eat', 'second_keyword': 'fruit', 'third_keyword': '--'},
#   'WELLNESS'),
#  ({'first_keyword': 'paradox',
#    'second_keyword': 'dying',
#    'third_keyword': 'lonely'},
#   'WELLNESS'),
#  ({'first_keyword': 'end',
#    'second_keyword': 'sexism',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'insomnia',
#    'second_keyword': 'linked',
#    'third_keyword': 'early'},
#   'WELLNESS'),
#  ({'first_keyword': 'soda',
#    'second_keyword': 'consumption',
#    'third_keyword': 'linked'},
#   'WELLNESS'),
#  ({'first_keyword': '7',
#    'second_keyword': 'worrisome',
#    'third_keyword': 'facts'},
#   'WELLNESS'),
#  ({'first_keyword': 'mayor',
#    'second_keyword': "bloomberg's",
#    'third_keyword': 'new'},
#   'WELLNESS'),
#  ({'first_keyword': 'gym:',
#    'second_keyword': 'fitness',
#    'third_keyword': 'etiquette'},
#   'WELLNESS'),
#  ({'first_keyword': 'exercise',
#    'second_keyword': 'stresses',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'easter',
#    'second_keyword': 'candy:',
#    'third_keyword': 'many'},
#   'WELLNESS'),
#  ({'first_keyword': 'doctor',
#    'second_keyword': 'shopping:',
#    'third_keyword': 'states'},
#   'WELLNESS'),
#  ({'first_keyword': 'pets',
#    'second_keyword': 'looking',
#    'third_keyword': 'like'},
#   'WELLNESS'),
#  ({'first_keyword': 'feeling',
#    'second_keyword': 'hungry',
#    'third_keyword': 'healthy'},
#   'WELLNESS'),
#  ({'first_keyword': 'staying',
#    'second_keyword': 'holiday',
#    'third_keyword': 'fitness'},
#   'WELLNESS'),
#  ({'first_keyword': 'death',
#    'second_keyword': 'destroy',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'help',
#    'second_keyword': 'grieving',
#    'third_keyword': 'friend:'},
#   'WELLNESS'),
#  ({'first_keyword': 'workplace',
#    'second_keyword': 'will',
#    'third_keyword': 'future'},
#   'WELLNESS'),
#  ({'first_keyword': '10',
#    'second_keyword': 'office',
#    'third_keyword': 'personalities'},
#   'WELLNESS'),
#  ({'first_keyword': 'marquesha',
#    'second_keyword': 'fells',
#    'third_keyword': 'lost'},
#   'WELLNESS'),
#  ({'first_keyword': '6', 'second_keyword': 'things', 'third_keyword': 'need'},
#   'WELLNESS'),
#  ({'first_keyword': 'pick',
#    'second_keyword': 'best',
#    'third_keyword': 'mattress'},
#   'WELLNESS'),
#  ({'first_keyword': 'education',
#    'second_keyword': 'credible',
#    'third_keyword': 'science'},
#   'WELLNESS'),
#  ({'first_keyword': 'reaching',
#    'second_keyword': 'heart',
#    'third_keyword': 'spring'},
#   'WELLNESS'),
#  ({'first_keyword': 'stop',
#    'second_keyword': 'people',
#    'third_keyword': 'pleaser!'},
#   'WELLNESS'),
#  ({'first_keyword': 'fit',
#    'second_keyword': 'links:',
#    'third_keyword': 'type'},
#   'WELLNESS'),
#  ({'first_keyword': 'smokeout',
#    'second_keyword': 'day',
#    'third_keyword': '2012:'},
#   'WELLNESS'),
#  ({'first_keyword': 'elusive',
#    'second_keyword': 'vegan',
#    'third_keyword': 'man'},
#   'WELLNESS'),
#  ({'first_keyword': 'woman',
#    'second_keyword': '88-pound',
#    'third_keyword': 'tumor'},
#   'WELLNESS'),
#  ({'first_keyword': 'freestyle',
#    'second_keyword': 'rap',
#    'third_keyword': 'unlocks'},
#   'WELLNESS'),
#  ({'first_keyword': 'fearless:',
#    'second_keyword': 'break',
#    'third_keyword': 'dignity'},
#   'WELLNESS'),
#  ({'first_keyword': 'compound',
#    'second_keyword': 'high-fiber',
#    'third_keyword': 'foods'},
#   'WELLNESS'),
#  ({'first_keyword': 'self-realization',
#    'second_keyword': 'verse',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'paralysis',
#    'second_keyword': 'over-analysis',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'spouse',
#    'second_keyword': 'argue',
#    'third_keyword': 'drinking?'},
#   'WELLNESS'),
#  ({'first_keyword': 'planning',
#    'second_keyword': 'less',
#    'third_keyword': 'effective'},
#   'WELLNESS'),
#  ({'first_keyword': 'can',
#    'second_keyword': 'learn',
#    'third_keyword': 'lives'},
#   'WELLNESS'),
#  ({'first_keyword': '7', 'second_keyword': 'steps', 'third_keyword': 'happy'},
#   'WELLNESS'),
#  ({'first_keyword': 'soul-talk:',
#    'second_keyword': 'stuck',
#    'third_keyword': 'toxic'},
#   'WELLNESS'),
#  ({'first_keyword': 'true',
#    'second_keyword': 'fountain',
#    'third_keyword': 'youth'},
#   'WELLNESS'),
#  ({'first_keyword': 'living',
#    'second_keyword': "alzheimer's,",
#    'third_keyword': 'looking'},
#   'WELLNESS'),
#  ({'first_keyword': 'nba',
#    'second_keyword': 'treating',
#    'third_keyword': 'sleep'},
#   'WELLNESS'),
#  ({'first_keyword': 'susan', 'second_keyword': 'g.', 'third_keyword': 'komen'},
#   'WELLNESS'),
#  ({'first_keyword': 'feel',
#    'second_keyword': 'feelings',
#    'third_keyword': 'improve'},
#   'WELLNESS'),
#  ({'first_keyword': 'roadmap',
#    'second_keyword': 'work',
#    'third_keyword': 'week'},
#   'WELLNESS'),
#  ({'first_keyword': 'gene',
#    'second_keyword': 'variants',
#    'third_keyword': 'linked'},
#   'WELLNESS'),
#  ({'first_keyword': 'bpa',
#    'second_keyword': 'research',
#    'third_keyword': 'mice'},
#   'WELLNESS'),
#  ({'first_keyword': 'enjoy',
#    'second_keyword': 'cruise',
#    'third_keyword': 'vacation'},
#   'WELLNESS'),
#  ({'first_keyword': 'masters',
#    'second_keyword': "sex':",
#    'third_keyword': '12'},
#   'WELLNESS'),
#  ({'first_keyword': 'best',
#    'second_keyword': 'cities',
#    'third_keyword': 'exercise'},
#   'WELLNESS'),
#  ({'first_keyword': 'phil',
#    'second_keyword': 'jackson',
#    'third_keyword': 'mindfulness:'},
#   'WELLNESS'),
#  ({'first_keyword': 'tips',
#    'second_keyword': 'healthy',
#    'third_keyword': 'living'},
#   'WELLNESS'),
#  ({'first_keyword': 'navigating',
#    'second_keyword': 'new',
#    'third_keyword': 'year'},
#   'WELLNESS'),
#  ({'first_keyword': 'secret',
#    'second_keyword': 'wonderful',
#    'third_keyword': 'life:'},
#   'WELLNESS'),
#  ({'first_keyword': 'gift',
#    'second_keyword': 'emptiness',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'meditate',
#    'second_keyword': 'stress',
#    'third_keyword': 'awareness'},
#   'WELLNESS'),
#  ({'first_keyword': 'simple',
#    'second_keyword': 'ways',
#    'third_keyword': 'eat'},
#   'WELLNESS'),
#  ({'first_keyword': 'social',
#    'second_keyword': 'experiment',
#    'third_keyword': 'reveals'},
#   'WELLNESS'),
#  ({'first_keyword': 'huffpost',
#    'second_keyword': 'workouts:',
#    'third_keyword': 'oscar-winning'},
#   'WELLNESS'),
#  ({'first_keyword': 'clearing',
#    'second_keyword': 'resistance',
#    'third_keyword': '(video)'},
#   'WELLNESS'),
#  ({'first_keyword': 'fight',
#    'second_keyword': 'breast',
#    'third_keyword': 'cancer,'},
#   'WELLNESS'),
#  ({'first_keyword': 'stalking',
#    'second_keyword': 'fear,',
#    'third_keyword': 'part'},
#   'WELLNESS'),
#  ({'first_keyword': 'making',
#    'second_keyword': 'aids',
#    'third_keyword': 'history:'},
#   'WELLNESS'),
#  ({'first_keyword': 'honica',
#    'second_keyword': 'brittman',
#    'third_keyword': 'kidney'},
#   'WELLNESS'),
#  ({'first_keyword': 'anxiety',
#    'second_keyword': 'boosts',
#    'third_keyword': 'detection'},
#   'WELLNESS'),
#  ({'first_keyword': 'three',
#    'second_keyword': 'years',
#    'third_keyword': 'later'},
#   'WELLNESS'),
#  ({'first_keyword': '100',
#    'second_keyword': 'wonderful',
#    'third_keyword': 'ways'},
#   'WELLNESS'),
#  ({'first_keyword': '15', 'second_keyword': 'dos', 'third_keyword': "don'ts"},
#   'WELLNESS'),
#  ({'first_keyword': 'brains',
#    'second_keyword': 'forget',
#    'third_keyword': 'memories'},
#   'WELLNESS'),
#  ({'first_keyword': 'hard',
#    'second_keyword': 'human',
#    'third_keyword': 'spring'},
#   'WELLNESS'),
#  ({'first_keyword': 'tommy',
#    'second_keyword': 'smith',
#    'third_keyword': 'ditched'},
#   'WELLNESS'),
#  ({'first_keyword': 'hindsight,',
#    'second_keyword': 'now',
#    'third_keyword': 'sight'},
#   'WELLNESS'),
#  ({'first_keyword': 'wheelchair',
#    'second_keyword': 'wisdom:',
#    'third_keyword': 'stop'},
#   'WELLNESS'),
#  ({'first_keyword': 'choose',
#    'second_keyword': 'best',
#    'third_keyword': 'personal'},
#   'WELLNESS'),
#  ({'first_keyword': 'happens',
#    'second_keyword': 'body',
#    'third_keyword': 'just'},
#   'WELLNESS'),
#  ({'first_keyword': 'finding',
#    'second_keyword': 'meaning',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'please',
#    'second_keyword': 'meditate:',
#    'third_keyword': 'revealing'},
#   'WELLNESS'),
#  ({'first_keyword': 'falling',
#    'second_keyword': 'love',
#    'third_keyword': 'work'},
#   'WELLNESS'),
#  ({'first_keyword': 'want',
#    'second_keyword': 'great',
#    'third_keyword': 'meal?'},
#   'WELLNESS'),
#  ({'first_keyword': 'bacterial',
#    'second_keyword': 'meningitis',
#    'third_keyword': 'vaccine'},
#   'WELLNESS'),
#  ({'first_keyword': 'nora',
#    'second_keyword': 'ephron',
#    'third_keyword': 'leukemia:'},
#   'WELLNESS'),
#  ({'first_keyword': 'love', 'second_keyword': 'None', 'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': '365', 'second_keyword': 'days', 'third_keyword': 'you:'},
#   'WELLNESS'),
#  ({'first_keyword': 'gluten',
#    'second_keyword': 'dummies:',
#    'third_keyword': 'real'},
#   'WELLNESS'),
#  ({'first_keyword': 'secrets',
#    'second_keyword': 'behind',
#    'third_keyword': 'chronic'},
#   'WELLNESS'),
#  ({'first_keyword': 'stress',
#    'second_keyword': 'linked',
#    'third_keyword': 'headaches'},
#   'WELLNESS'),
#  ({'first_keyword': '75',
#    'second_keyword': 'pounds',
#    'third_keyword': 'lighter,'},
#   'WELLNESS'),
#  ({'first_keyword': 'paul',
#    'second_keyword': 'ryan',
#    'third_keyword': 'p90x:'},
#   'WELLNESS'),
#  ({'first_keyword': 'reasonable',
#    'second_keyword': 'certainty',
#    'third_keyword': 'harm?'},
#   'WELLNESS'),
#  ({'first_keyword': 'de-stress',
#    'second_keyword': 'holiday',
#    'third_keyword': 'mess:'},
#   'WELLNESS'),
#  ({'first_keyword': 'eating',
#    'second_keyword': 'turn',
#    'third_keyword': 'gut'},
#   'WELLNESS'),
#  ({'first_keyword': 'heaven',
#    'second_keyword': 'haven?',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'taking',
#    'second_keyword': 'timeouts',
#    'third_keyword': 'decrease'},
#   'WELLNESS'),
#  ({'first_keyword': "brain's",
#    'second_keyword': "'sleep",
#    'third_keyword': "switch'"},
#   'WELLNESS'),
#  ({'first_keyword': 'kick',
#    'second_keyword': 'coffee',
#    'third_keyword': 'habit'},
#   'WELLNESS'),
#  ({'first_keyword': 'can', 'second_keyword': 'yogi', 'third_keyword': 'chai'},
#   'WELLNESS'),
#  ({'first_keyword': 'fondue',
#    'second_keyword': 'vision',
#    'third_keyword': 'boards:'},
#   'WELLNESS'),
#  ({'first_keyword': 'super',
#    'second_keyword': 'thoughts:',
#    'third_keyword': '5'},
#   'WELLNESS'),
#  ({'first_keyword': 'embrace',
#    'second_keyword': 'inner',
#    'third_keyword': 'scarlett'},
#   'WELLNESS'),
#  ({'first_keyword': 'temporary',
#    'second_keyword': 'tattoo',
#    'third_keyword': 'gauges'},
#   'WELLNESS'),
#  ({'first_keyword': 'new',
#    'second_keyword': 'doctor',
#    'third_keyword': 'harder'},
#   'WELLNESS'),
#  ({'first_keyword': 'yearly',
#    'second_keyword': 'mammograms',
#    'third_keyword': 'tied'},
#   'WELLNESS'),
#  ({'first_keyword': 'dare',
#    'second_keyword': '100:',
#    'third_keyword': 'physical'},
#   'WELLNESS'),
#  ({'first_keyword': 'dental',
#    'second_keyword': 'crisis',
#    'third_keyword': 'looms'},
#   'WELLNESS'),
#  ({'first_keyword': 'intention...',
#    'second_keyword': 'preparation...',
#    'third_keyword': 'action...'},
#   'WELLNESS'),
#  ({'first_keyword': '5', 'second_keyword': 'things', 'third_keyword': 'stay'},
#   'WELLNESS'),
#  ({'first_keyword': 'boxes',
#    'second_keyword': 'old',
#    'third_keyword': 'letters?'},
#   'WELLNESS'),
#  ({'first_keyword': 'worst',
#    'second_keyword': 'diet',
#    'third_keyword': 'mistakes'},
#   'WELLNESS'),
#  ({'first_keyword': 'strawberries',
#    'second_keyword': 'blueberries',
#    'third_keyword': 'decrease'},
#   'WELLNESS'),
#  ({'first_keyword': 'find', 'second_keyword': 'joy', 'third_keyword': 'even'},
#   'WELLNESS'),
#  ({'first_keyword': 'body',
#    'second_keyword': 'mirror',
#    'third_keyword': 'thought?'},
#   'WELLNESS'),
#  ({'first_keyword': 'important',
#    'second_keyword': 'distinction',
#    'third_keyword': 'exercising'},
#   'WELLNESS'),
#  ({'first_keyword': 'lost',
#    'second_keyword': 'weight:',
#    'third_keyword': 'janne'},
#   'WELLNESS'),
#  ({'first_keyword': 'yogi',
#    'second_keyword': 'vegetarian?',
#    'third_keyword': 'closer'},
#   'WELLNESS'),
#  ({'first_keyword': 'torn',
#    'second_keyword': 'valentine',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': '75-year',
#    'second_keyword': 'study',
#    'third_keyword': 'found'},
#   'WELLNESS'),
#  ({'first_keyword': 'learn',
#    'second_keyword': 'mistakes',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'simple',
#    'second_keyword': 'secret',
#    'third_keyword': 'living'},
#   'WELLNESS'),
#  ({'first_keyword': 'ideal',
#    'second_keyword': 'warm-up?',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'end-of-life',
#    'second_keyword': 'conversation',
#    'third_keyword': 'midst'},
#   'WELLNESS'),
#  ({'first_keyword': 'fearless',
#    'second_keyword': 'living',
#    'third_keyword': 'boot'},
#   'WELLNESS'),
#  ({'first_keyword': 'ge',
#    'second_keyword': 'foods',
#    'third_keyword': 'shorten'},
#   'WELLNESS'),
#  ({'first_keyword': '5', 'second_keyword': 'special', 'third_keyword': 'ways'},
#   'WELLNESS'),
#  ({'first_keyword': '8', 'second_keyword': 'scary', 'third_keyword': 'things'},
#   'WELLNESS'),
#  ({'first_keyword': 'cosmetic',
#    'second_keyword': 'fillers',
#    'third_keyword': 'cause'},
#   'WELLNESS'),
#  ({'first_keyword': "dsm-5's",
#    'second_keyword': 'new',
#    'third_keyword': 'approach'},
#   'WELLNESS'),
#  ({'first_keyword': 'superfood',
#    'second_keyword': 'death',
#    'third_keyword': 'match:'},
#   'WELLNESS'),
#  ({'first_keyword': 'trichotillomania:',
#    'second_keyword': 'disorder',
#    'third_keyword': 'makes'},
#   'WELLNESS'),
#  ({'first_keyword': 'difference',
#    'second_keyword': 'hour',
#    'third_keyword': 'can'},
#   'WELLNESS'),
#  ({'first_keyword': 'hindsight',
#    'second_keyword': 'cancer',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'sitting',
#    'second_keyword': 'tall:',
#    'third_keyword': 'letting'},
#   'WELLNESS'),
#  ({'first_keyword': 'runners:',
#    'second_keyword': 'let',
#    'third_keyword': 'poor'},
#   'WELLNESS'),
#  ({'first_keyword': 'fitness',
#    'second_keyword': 'myths',
#    'third_keyword': 'hold'},
#   'WELLNESS'),
#  ({'first_keyword': 'fit',
#    'second_keyword': 'links:',
#    'third_keyword': 'signs'},
#   'WELLNESS'),
#  ({'first_keyword': '7', 'second_keyword': 'tips', 'third_keyword': 'making'},
#   'WELLNESS'),
#  ({'first_keyword': 'vegetable',
#    'second_keyword': 'fats',
#    'third_keyword': 'help'},
#   'WELLNESS'),
#  ({'first_keyword': 'pancreatic',
#    'second_keyword': 'cancer:',
#    'third_keyword': "'game"},
#   'WELLNESS'),
#  ({'first_keyword': 'dating',
#    'second_keyword': 'sometimes',
#    'third_keyword': 'like'},
# ...
#   'WELLNESS'),
#  ({'first_keyword': 'meditate:',
#    'second_keyword': '19',
#    'third_keyword': 'reasons'},
#   'WELLNESS'),
#  ({'first_keyword': 'overcome',
#    'second_keyword': 'negative',
#    'third_keyword': 'effects'},
#   'WELLNESS'),
#  ({'first_keyword': 'chewing',
#    'second_keyword': 'gum',
#    'third_keyword': 'lead'},
#   'WELLNESS'),
#  ({'first_keyword': 'chronic',
#    'second_keyword': 'stress:',
#    'third_keyword': 'hidden'},
#   'WELLNESS'),
#  ({'first_keyword': 'count',
#    'second_keyword': 'burdens',
#    'third_keyword': 'better'},
#   'WELLNESS'),
#  ({'first_keyword': 'new',
#    'second_keyword': 'mainstream',
#    'third_keyword': 'health'},
#   'WELLNESS'),
#  ({'first_keyword': 'childhood',
#    'second_keyword': 'socioeconomic',
#    'third_keyword': 'status'},
#   'WELLNESS'),
#  ({'first_keyword': 'victoria',
#    'second_keyword': "secret's",
#    'third_keyword': 'doutzen'},
#   'WELLNESS'),
#  ({'first_keyword': 'necessary',
#    'second_keyword': 'change',
#    'third_keyword': 'happiness'},
#   'WELLNESS'),
#  ({'first_keyword': 'friends',
#    'second_keyword': 'see',
#    'third_keyword': 'eye-to-eye'},
#   'WELLNESS'),
#  ({'first_keyword': 'handle',
#    'second_keyword': 'control',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': '45', 'second_keyword': 'days', 'third_keyword': '45:'},
#   'WELLNESS'),
#  ({'first_keyword': 'crossfitters',
#    'second_keyword': 'athletes',
#    'third_keyword': 'benefit'},
#   'WELLNESS'),
#  ({'first_keyword': '10-minute',
#    'second_keyword': 'cardio',
#    'third_keyword': 'workout'},
#   'WELLNESS'),
#  ({'first_keyword': 'ask',
#    'second_keyword': 'scientist:',
#    'third_keyword': 'cracking'},
#   'WELLNESS'),
#  ({'first_keyword': '10', 'second_keyword': 'ways', 'third_keyword': 'reduce'},
#   'WELLNESS'),
#  ({'first_keyword': 'navigating',
#    'second_keyword': 'heart:',
#    'third_keyword': 'free'},
#   'WELLNESS'),
#  ({'first_keyword': '8',
#    'second_keyword': 'effective',
#    'third_keyword': 'strength-training'},
#   'WELLNESS'),
#  ({'first_keyword': '6th',
#    'second_keyword': "'most",
#    'third_keyword': 'fearless'},
#   'WELLNESS'),
#  ({'first_keyword': 'iclusig:',
#    'second_keyword': 'leukemia',
#    'third_keyword': 'drug'},
#   'WELLNESS'),
#  ({'first_keyword': 'dos',
#    'second_keyword': "don'ts",
#    'third_keyword': 'dealing'},
#   'WELLNESS'),
#  ({'first_keyword': 'french',
#    'second_keyword': 'women',
#    'third_keyword': 'work'},
#   'WELLNESS'),
#  ({'first_keyword': '5', 'second_keyword': 'ways', 'third_keyword': 'healthy'},
#   'WELLNESS'),
#  ({'first_keyword': 'canine',
#    'second_keyword': "wobbler's",
#    'third_keyword': 'syndrome'},
#   'WELLNESS'),
#  ({'first_keyword': '10', 'second_keyword': 'things', 'third_keyword': 'will'},
#   'WELLNESS'),
#  ({'first_keyword': 'personhood:',
#    'second_keyword': 'causality',
#    'third_keyword': 'modern'},
#   'WELLNESS'),
#  ({'first_keyword': 'obesity',
#    'second_keyword': 'shorter',
#    'third_keyword': 'lifespans:'},
#   'WELLNESS'),
#  ({'first_keyword': 'sugar',
#    'second_keyword': 'cravings',
#    'third_keyword': 'sweetie'},
#   'WELLNESS'),
#  ({'first_keyword': 'seeking',
#    'second_keyword': 'enlightenment?',
#    'third_keyword': 'take'},
#   'WELLNESS'),
#  ({'first_keyword': '7', 'second_keyword': 'reasons', 'third_keyword': 'eat'},
#   'WELLNESS'),
#  ({'first_keyword': 'loving',
#    'second_keyword': 'reflection',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'industry',
#    'second_keyword': "'undue",
#    'third_keyword': "influence'"},
#   'WELLNESS'),
#  ({'first_keyword': 'living',
#    'second_keyword': 'resume',
#    'third_keyword': 'eulogy?'},
#   'WELLNESS'),
#  ({'first_keyword': 'confronting',
#    'second_keyword': 'fears:',
#    'third_keyword': "'my"},
#   'WELLNESS'),
#  ({'first_keyword': 'running',
#    'second_keyword': 'form:',
#    'third_keyword': 'distilled'},
#   'WELLNESS'),
#  ({'first_keyword': 'connecting:',
#    'second_keyword': 'easy',
#    'third_keyword': 'turning'},
#   'WELLNESS'),
#  ({'first_keyword': 'trauma-sensitive',
#    'second_keyword': 'yoga',
#    'third_keyword': 'therapy'},
#   'WELLNESS'),
#  ({'first_keyword': 'hardship',
#    'second_keyword': 'hits:',
#    'third_keyword': 'ask'},
#   'WELLNESS'),
#  ({'first_keyword': 'fearless',
#    'second_keyword': 'memoir:',
#    'third_keyword': "'world's"},
#   'WELLNESS'),
#  ({'first_keyword': 'fun',
#    'second_keyword': 'workplace?',
#    'third_keyword': '(and'},
#   'WELLNESS'),
#  ({'first_keyword': 'tried',
#    'second_keyword': 'it:',
#    'third_keyword': 'lacey'},
#   'WELLNESS'),
#  ({'first_keyword': 'soul',
#    'second_keyword': 'mindfulness:',
#    'third_keyword': '7'},
#   'WELLNESS'),
#  ({'first_keyword': 'going', 'second_keyword': 'take', 'third_keyword': 'get'},
#   'WELLNESS'),
#  ({'first_keyword': 'blood',
#    'second_keyword': 'sugar',
#    'third_keyword': 'solution'},
#   'WELLNESS'),
#  ({'first_keyword': 'buy',
#    'second_keyword': 'healthiest',
#    'third_keyword': 'yogurt'},
#   'WELLNESS'),
#  ({'first_keyword': 'life',
#    'second_keyword': 'lessons',
#    'third_keyword': 'learned'},
#   'WELLNESS'),
#  ({'first_keyword': 'staying',
#    'second_keyword': 'clean',
#    'third_keyword': 'christmas'},
#   'WELLNESS'),
#  ({'first_keyword': 'breakdown',
#    'second_keyword': 'breakthrough:',
#    'third_keyword': 'life'},
#   'WELLNESS'),
#  ({'first_keyword': 'yoga',
#    'second_keyword': 'playlist',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'breathing',
#    'second_keyword': 'right',
#    'third_keyword': 'bones'},
#   'WELLNESS'),
#  ({'first_keyword': 'embracing',
#    'second_keyword': 'fear',
#    'third_keyword': 'relationships'},
#   'WELLNESS'),
#  ({'first_keyword': 'living',
#    'second_keyword': 'balanced',
#    'third_keyword': 'healthy'},
#   'WELLNESS'),
#  ({'first_keyword': 'head,',
#    'second_keyword': 'body',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'lessons',
#    'second_keyword': 'fast',
#    'third_keyword': 'lane'},
#   'WELLNESS'),
#  ({'first_keyword': 'miss',
#    'second_keyword': 'grinch',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'mold',
#    'second_keyword': 'flooding',
#    'third_keyword': 'pose'},
#   'WELLNESS'),
#  ({'first_keyword': 'sitting',
#    'second_keyword': 'mother',
#    'third_keyword': 'meera'},
#   'WELLNESS'),
#  ({'first_keyword': 'lost',
#    'second_keyword': 'weight:',
#    'third_keyword': 'concerned'},
#   'WELLNESS'),
#  ({'first_keyword': 'people',
#    'second_keyword': 'get',
#    'third_keyword': 'awesome'},
#   'WELLNESS'),
#  ({'first_keyword': 'training',
#    'second_keyword': 'tips',
#    'third_keyword': 'olympic'},
#   'WELLNESS'),
#  ({'first_keyword': 'yoga:',
#    'second_keyword': 'helping',
#    'third_keyword': "'united"},
#   'WELLNESS'),
#  ({'first_keyword': 'day',
#    'second_keyword': 'thanks,',
#    'third_keyword': 'vice'},
#   'WELLNESS'),
#  ({'first_keyword': 'summer',
#    'second_keyword': 'cool',
#    'third_keyword': 'poses'},
#   'WELLNESS'),
#  ({'first_keyword': 'perfect',
#    'second_keyword': 'workout',
#    'third_keyword': 'partner:'},
#   'WELLNESS'),
#  ({'first_keyword': 'tall',
#    'second_keyword': 'women',
#    'third_keyword': 'cancer:'},
#   'WELLNESS'),
#  ({'first_keyword': 'stress-less',
#    'second_keyword': 'april',
#    'third_keyword': 'twitter'},
#   'WELLNESS'),
#  ({'first_keyword': 'watch:',
#    'second_keyword': 'tap',
#    'third_keyword': 'fears!'},
#   'WELLNESS'),
#  ({'first_keyword': 'cheap,',
#    'second_keyword': 'thoughtful',
#    'third_keyword': 'healthy:'},
#   'WELLNESS'),
#  ({'first_keyword': 'setting',
#    'second_keyword': 'goals',
#    'third_keyword': 'work'},
#   'WELLNESS'),
#  ({'first_keyword': 'cuban',
#    'second_keyword': 'happiness',
#    'third_keyword': 'side'},
#   'WELLNESS'),
#  ({'first_keyword': 'bad',
#    'second_keyword': 'breath',
#    'third_keyword': 'faqs'},
#   'WELLNESS'),
#  ({'first_keyword': 'added',
#    'second_keyword': 'fructose',
#    'third_keyword': 'high'},
#   'WELLNESS'),
#  ({'first_keyword': 'psychological',
#    'second_keyword': 'stretch',
#    'third_keyword': 'marks'},
#   'WELLNESS'),
#  ({'first_keyword': '5', 'second_keyword': 'ways', 'third_keyword': 'create'},
#   'WELLNESS'),
#  ({'first_keyword': '2012:',
#    'second_keyword': 'best',
#    'third_keyword': 'year'},
#   'WELLNESS'),
#  ({'first_keyword': 'boyfriend',
#    'second_keyword': 'riley',
#    'third_keyword': 'nicolay'},
#   'WELLNESS'),
#  ({'first_keyword': 'moment',
#    'second_keyword': 'knew',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': '7', 'second_keyword': 'tips', 'third_keyword': 'beat'},
#   'WELLNESS'),
#  ({'first_keyword': 'hate',
#    'second_keyword': 'gluten-free',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'cancer',
#    'second_keyword': 'diagnosis:',
#    'third_keyword': 'alone,'},
#   'WELLNESS'),
#  ({'first_keyword': 'impossible',
#    'second_keyword': 'becomes',
#    'third_keyword': 'possible'},
#   'WELLNESS'),
#  ({'first_keyword': 'restaurant',
#    'second_keyword': 'survival',
#    'third_keyword': 'guide:'},
#   'WELLNESS'),
#  ({'first_keyword': 'titanic:',
#    'second_keyword': 'deeper',
#    'third_keyword': 'life'},
#   'WELLNESS'),
#  ({'first_keyword': 'someone',
#    'second_keyword': 'asks',
#    'third_keyword': 'favor'},
#   'WELLNESS'),
#  ({'first_keyword': 'leave',
#    'second_keyword': '(kidney)',
#    'third_keyword': 'stone'},
#   'WELLNESS'),
#  ({'first_keyword': 'egg',
#    'second_keyword': 'white',
#    'third_keyword': 'breakfast'},
#   'WELLNESS'),
#  ({'first_keyword': 'cold',
#    'second_keyword': 'weather',
#    'third_keyword': 'pain:'},
#   'WELLNESS'),
#  ({'first_keyword': 'kamala',
#    'second_keyword': "nayeli's",
#    'third_keyword': 'tools'},
#   'WELLNESS'),
#  ({'first_keyword': 'immunotoxin',
#    'second_keyword': '3b3-pe38',
#    'third_keyword': 'kill'},
#   'WELLNESS'),
#  ({'first_keyword': 'yoga',
#    'second_keyword': 'kids:',
#    'third_keyword': 'benefits'},
#   'WELLNESS'),
#  ({'first_keyword': 'oregano',
#    'second_keyword': 'oil',
#    'third_keyword': 'compound'},
#   'WELLNESS'),
#  ({'first_keyword': 'ask',
#    'second_keyword': 'celebrity',
#    'third_keyword': 'trainer:'},
#   'WELLNESS'),
#  ({'first_keyword': 'parent/caregiver:',
#    'second_keyword': 'patience,',
#    'third_keyword': 'compassion'},
#   'WELLNESS'),
#  ({'first_keyword': '7',
#    'second_keyword': 'superfoods',
#    'third_keyword': 'help'},
#   'WELLNESS'),
#  ({'first_keyword': 'got',
#    'second_keyword': 'pain?',
#    'third_keyword': 'learn'},
#   'WELLNESS'),
#  ({'first_keyword': '6', 'second_keyword': 'trx', 'third_keyword': 'workout'},
#   'WELLNESS'),
#  ({'first_keyword': 'listen',
#    'second_keyword': 'heart:',
#    'third_keyword': '5'},
#   'WELLNESS'),
#  ({'first_keyword': 'injectable',
#    'second_keyword': 'foam',
#    'third_keyword': 'blocks'},
#   'WELLNESS'),
#  ({'first_keyword': 'long-lasting',
#    'second_keyword': 'effects',
#    'third_keyword': 'meditation'},
#   'WELLNESS'),
#  ({'first_keyword': 'polar',
#    'second_keyword': 'vortex',
#    'third_keyword': 'actually'},
#   'WELLNESS'),
#  ({'first_keyword': 'makes',
#    'second_keyword': "'good'",
#    'third_keyword': 'personal'},
#   'WELLNESS'),
#  ({'first_keyword': 'zombie',
#    'second_keyword': 'apocalypse!',
#    'third_keyword': 'iphone'},
#   'WELLNESS'),
#  ({'first_keyword': 'electric',
#    'second_keyword': 'light',
#    'third_keyword': 'harming'},
#   'WELLNESS'),
#  ({'first_keyword': 'cleaner',
#    'second_keyword': 'air',
#    'third_keyword': 'may'},
#   'WELLNESS'),
#  ({'first_keyword': '3', 'second_keyword': 'hot', 'third_keyword': 'fitness'},
#   'WELLNESS'),
#  ({'first_keyword': 'clear-skin',
#    'second_keyword': 'secrets',
#    'third_keyword': 'sweaty'},
#   'WELLNESS'),
#  ({'first_keyword': 'vaccine',
#    'second_keyword': 'glioblastoma',
#    'third_keyword': 'multiforme'},
#   'WELLNESS'),
#  ({'first_keyword': '6', 'second_keyword': 'ways', 'third_keyword': 'rock'},
#   'WELLNESS'),
#  ({'first_keyword': 'daily',
#    'second_keyword': 'habit',
#    'third_keyword': 'helps'},
#   'WELLNESS'),
#  ({'first_keyword': 'singling',
#    'second_keyword': 'holidays',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'can',
#    'second_keyword': 'obesity',
#    'third_keyword': 'malnutrition'},
#   'WELLNESS'),
#  ({'first_keyword': '8',
#    'second_keyword': 'pieces',
#    'third_keyword': 'wisdom'},
#   'WELLNESS'),
#  ({'first_keyword': 'weight',
#    'second_keyword': 'loss',
#    'third_keyword': 'success:'},
#   'WELLNESS'),
#  ({'first_keyword': 'h7n9,',
#    'second_keyword': 'current',
#    'third_keyword': 'bird'},
#   'WELLNESS'),
#  ({'first_keyword': 'fearless',
#    'second_keyword': 'memoir:',
#    'third_keyword': "'world's"},
#   'WELLNESS'),
#  ({'first_keyword': 'ragwitek:',
#    'second_keyword': 'fda',
#    'third_keyword': 'panel'},
#   'WELLNESS'),
#  ({'first_keyword': 'vintage',
#    'second_keyword': 'weight',
#    'third_keyword': 'loss'},
#   'WELLNESS'),
#  ({'first_keyword': '10',
#    'second_keyword': 'ways',
#    'third_keyword': 'improve'},
#   'WELLNESS'),
#  ({'first_keyword': 'acceptance',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'parenting',
#    'second_keyword': 'made',
#    'third_keyword': "brave'"},
#   'WELLNESS'),
#  ({'first_keyword': '4', 'second_keyword': 'ways', 'third_keyword': 'healthy'},
#   'WELLNESS'),
#  ({'first_keyword': 'vegan-inspired',
#    'second_keyword': 'thanksgivukkah',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'grandparents',
#    'second_keyword': 'ate',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'aggressive',
#    'second_keyword': 'prostate',
#    'third_keyword': 'cancer'},
#   'WELLNESS'),
#  ({'first_keyword': 'fear',
#    'second_keyword': 'grief:',
#    'third_keyword': "'when"},
#   'WELLNESS'),
#  ({'first_keyword': 'shopping',
#    'second_keyword': 'health',
#    'third_keyword': 'care'},
#   'WELLNESS'),
#  ({'first_keyword': 'shrink',
#    'second_keyword': 'fat!',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'living',
#    'second_keyword': '(and',
#    'third_keyword': 'dying)'},
#   'WELLNESS'),
#  ({'first_keyword': 'recovering',
#    'second_keyword': "'hurry",
#    'third_keyword': "sickness'"},
#   'WELLNESS'),
#  ({'first_keyword': 'duality',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'last',
#    'second_keyword': 'breaths',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'exercise',
#    'second_keyword': 'lower',
#    'third_keyword': 'fatigue'},
#   'WELLNESS'),
#  ({'first_keyword': 'crash',
#    'second_keyword': 'diet',
#    'third_keyword': 'work'},
#   'WELLNESS'),
#  ({'first_keyword': 'codependency,',
#    'second_keyword': 'dance!',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': '37',
#    'second_keyword': 'life',
#    'third_keyword': 'lessons'},
#   'WELLNESS'),
#  ({'first_keyword': 'small',
#    'second_keyword': 'steps',
#    'third_keyword': 'help'},
#   'WELLNESS'),
#  ({'first_keyword': 'main',
#    'second_keyword': 'event',
#    'third_keyword': 'None'},
#   'WELLNESS'),
#  ({'first_keyword': 'new',
#    'second_keyword': 'yorker',
#    'third_keyword': 'cartoons'},
#   'WELLNESS'),
#  ({'first_keyword': 'meditation',
#    'second_keyword': 'busting',
#    'third_keyword': 'blocks'},
#   'WELLNESS'),
#  ({'first_keyword': 'copper',
#    'second_keyword': 'play',
#    'third_keyword': 'role'},
#   'WELLNESS'),
#  ({'first_keyword': 'lesson',
#    'second_keyword': 'karma',
#    'third_keyword': 'song'},
#   'WELLNESS'),
#  ({'first_keyword': '5', 'second_keyword': 'foods', 'third_keyword': 'still'},
#   'WELLNESS'),
#  ({'first_keyword': '6', 'second_keyword': 'ways', 'third_keyword': 'singles'},
#   'WELLNESS'),
#  ({'first_keyword': 'says,',
#    'second_keyword': "'pardon",
#    'third_keyword': 'me,'},
#   'WELLNESS'),
#  ({'first_keyword': 'dadmissions:',
#    'second_keyword': "mother's",
#    'third_keyword': 'final'},
#   'WELLNESS'),
#  ({'first_keyword': 'can',
#    'second_keyword': 'laughter',
#    'third_keyword': 'count'},
#   'WELLNESS'),
#  ({'first_keyword': 'chocolate-eating',
#    'second_keyword': 'teens',
#    'third_keyword': 'less'},
#   'WELLNESS'),
#  ({'first_keyword': 'flirtation',
#    'second_keyword': 'infidelity?',
#    'third_keyword': 'okay'},
#   'WELLNESS'),
#  ({'first_keyword': 'toxic',
#    'second_keyword': 'chemical',
#    'third_keyword': 'food'},
#   'WELLNESS'),
#  ...]

# %%
import random
random.shuffle(feature_sets)

# %%
import math

# calculating what 80% of our data set is
split_num = math.floor(len(feature_sets) * .8)

# 80% of my data
training_set = feature_sets[:split_num]
# 20% of my data
testing_set = feature_sets[split_num:]

# %%
import nltk

classifier = nltk.NaiveBayesClassifier.train(training_set)

# %%
classifier.classify(create_features("Resting is part of training. I've confirmed what I sort of already knew: I'm not built for running streaks. I'm built for hard workouts three to five days a week with lots of cross training, physical therapy and foam rolling. But I've also confirmed that I'm stubborn with myself."))
# Out:
# 'ENTERTAINMENT'

# %%
print(nltk.classify.accuracy(classifier, testing_set))
# Out:
# 0.5986

# %%
classifier.show_most_informative_features(12)
# Out:
# Most Informative Features
#            third_keyword = 'recipes'      FOOD & : WELLNE =     86.2 : 1.0
#           second_keyword = 'day:'         FOOD & : POLITI =     80.3 : 1.0
#            first_keyword = 'recipe'       FOOD & : BUSINE =     79.6 : 1.0
#            third_keyword = 'style'        STYLE  : ENTERT =     77.7 : 1.0
#            first_keyword = 'women'        BUSINE : FOOD & =     73.0 : 1.0
#           second_keyword = 'recipes'      FOOD & : TRAVEL =     71.3 : 1.0
#            third_keyword = 'fashion'      STYLE  : PARENT =     64.0 : 1.0
#            first_keyword = 'nfl'          SPORTS : POLITI =     60.9 : 1.0
#           second_keyword = 'travel'       TRAVEL : POLITI =     60.1 : 1.0
#            first_keyword = 'best'         FOOD & : WORLD  =     59.7 : 1.0
#           second_keyword = 'business'     BUSINE : PARENT =     57.0 : 1.0
#           second_keyword = 'best'         TRAVEL : WORLD  =     56.8 : 1.0
